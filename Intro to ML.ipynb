# %% [markdown]
# BOSTON DATA

# %%
import pandas as pd
import numpy as np
from sklearn import datasets

# %%
boston= datasets.load_boston()

# %% [markdown]
# ## Features
# - CRIM:     per capita crime rate by town\n
# - ZN:       proportion of residential land zoned for lots over 25,000 sq.ft.\n
# - INDUS:    proportion of non-retail business acres per town\n
# - CHAS:     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n
# - NOX:      nitric oxides concentration (parts per 10 million)\n
# - RM:       average number of rooms per dwelling\n
# - AGE:      proportion of owner-occupied units built prior to 1940\n
# - DIS:      weighted distances to five Boston employment centres\n
# - RAD:      index of accessibility to radial highways\n
# - TAX:      full-value property-tax rate per $10,000\n
# - PTRATIO:  pupil-teacher ratio by town\n
# - B:        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town\n
# - LSTAT:    % lower status of the population\n

# %%
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
x = boston.data
y = boston.target

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.shape #506 data points and each data point has 13 features(variables)
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
#convert the boston data to data frame 
df = pd.DataFrame(x)

# %%
df.columns = boston.feature_names

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#to split data
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(x,y)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (379, 13)
# (127, 13)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (379,)
# (127,)

# %%
from sklearn.linear_model import LinearRegression
algo1 = LinearRegression()

# %%
algo1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = algo1.predict(x_test)

# %%
y_pred
# Out:
# array([32.92610161, 40.25546642, 25.15712596, 23.44100416, 16.23137967,
#        13.24576623, 29.67104015, 31.12340969, 25.24948085, 20.91865871,
#        19.90756414, 19.72893292, 18.06166434, 13.27345373, 20.30733262,
#        13.61400133, 28.20807504, 13.96426444, 22.50913234, 16.04510576,
#        22.54577672, 24.87762872, 20.96397732, 23.51835405, 19.11476257,
#        32.32744449, 23.67123442, 23.38451572, 27.06001736, 23.9285177 ,
#        11.19468127, 20.63456016, 19.06914914, 20.10840736, 17.27525258,
#        20.06485146, 24.79662075, 19.54164096, 27.34538971, 20.92694635,
#        17.59529251,  7.04131785, 19.30554207, 20.77580224, 23.18817983,
#        23.36171085,  5.95715245, 13.94930666, 12.46441619,  3.56095446,
#        22.89854408, 23.71246402, 21.07526139, 22.5940993 , 33.2114073 ,
#        24.72586258, 18.42821288, 28.9765224 , 34.22874829, 14.24456174,
#        32.85082506, 29.94790166, 17.83882712, 27.4740455 , 23.26961508,
# ...

# %%
# now to see if its good or bad, we compare y_pred and y_test(original output)
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.axis ([0,40,0,40])
plt.show()

# %% [markdown]
# ## Diabetes Dataset

# %%
diab = datasets.load_diabetes()

# %% [markdown]
# ## Features
# Age:
# Sex:
# Bmi:
# BP:
# S1:tc, T-Cells
# S2:ldl, low-density lipoproteins
# S3: hdl, high-density lipoproteins
# S4:tch, thyroid stimulating hormone
# S5:ltg, lamotrigine
# S6:glu, blood sugar level

# %%
X = diab.data
y= diab.target

# %%
X.shape
# Out:
# (442, 10)

# %%
Y.shape
# Out:
# (442,)

# %%
df = pd.DataFrame(X)
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#             7         8         9
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
df.columns = diab.feature_names
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
from sklearn import model_selection
X_train,X_test,Y_train,Y_test=model_selection.train_test_split(X,Y)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (331, 10)
# (111, 10)
# (331,)
# (111,)

# %%
from sklearn.linear_model import LinearRegression
alg1 = LinearRegression()

# %%
alg1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = alg1.predict(X_test)

# %%
Y_pred
# Out:
# array([180.92926001, 190.37060211, 117.88071043, 188.09492222,
#        174.74762846, 110.13827922, 244.0326412 , 166.02795303,
#        110.71157233, 175.61353731, 139.87171332, 211.82002023,
#        101.07728112,  61.72458827, 193.52890928, 195.7967421 ,
#        157.95748867,  70.68307797, 102.14108442, 209.3277361 ,
#        192.29603835, 160.76666537, 256.96584958,  51.40735472,
#        229.16869201,  94.76048214, 204.99446476, 283.31473175,
#        190.70908188, 144.12662238, 119.29710615,  87.62340694,
#        170.40476786, 108.87688958, 247.22054367, 117.01203969,
#         82.24976112, 175.51246195, 116.11907317, 147.50736156,
#        188.61406034, 140.99595407, 117.28072094, 229.2434045 ,
#        110.92003701,  59.13079324, 177.82350461, 191.11903582,
#        240.20726341, 141.10747557,  81.88776106, 176.85707407,
#        235.34419743, 158.56770047, 214.8179491 , 138.47623874,
#        130.33334032, 120.5897085 ,  63.4936474 , 150.52647518,
# ...

# %%
plt.scatter(Y_test,Y_pred,color = 'r')
plt.axis ([20,400,20,300])
plt.show()
